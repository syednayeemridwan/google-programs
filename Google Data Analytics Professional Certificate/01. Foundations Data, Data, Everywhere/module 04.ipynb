# %% [markdown]
# # Consider fairness

# %% [markdown]
# 1. Consider all of the available data
# 2. Identify surrounding factors
# 3. Include self-reported data
# 4. Use oversampling effectively
# 5. Think about fairness from beginning to end
#
#
# Sampling should be random and represent entire population in all conditions and all factors equally distributed. otherwise there will be bound to be bias.
