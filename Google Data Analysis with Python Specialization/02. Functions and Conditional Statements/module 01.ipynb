# %% [markdown]
# # Function

# %% [markdown]
# - body of re-usable code that performs specific tasks
# - Modularity = The ability to write code in separate components (blocks of sections of code) that work together and that can be re-used in other programs
# - Refactoring = the process of restructuring code while maintaining its original functionality. used for self-documenting code
# - Self documenting code = code written in a way that is readable and make the purpose clear
# - Use comments to break down the thought process step by step towards a feasible solution.
# - Doc string= use it to describe what a function does, parameters, and what it returns
# - Functions and methods are very similar, but there are a few key differences. Methods are a specific type of function. They are functions that belong to a class. This means that you can use them—or “call” them—by using dot notation.
# - see documentation: https://docs.python.org/3/library/
# - there are built-in functions: https://docs.python.org/3/library/functions.html

# %% [markdown]
# # Ideal Example

# %%
from typing import List

def calculate_average(numbers: List[float]) -> float:
    """
    Calculate the average (mean) of a list of numbers.

    Args:
        numbers (List[float]): A list of numeric values.

    Returns:
        float: The average of the numbers.

    Raises:
        ValueError: If the input list is empty.

    Example:
        >>> calculate_average([1, 2, 3, 4])
        2.5
    """
    # Check if the input list is empty
    if not numbers:
        raise ValueError("The list of numbers cannot be empty.")

    # Compute the sum of all elements
    total = sum(numbers)

    # Count the number of elements
    count = len(numbers)

    # Calculate and return the average
    return total / count
