# %% [markdown]
# # Input Validation

# %% [markdown]
# - Check and recheck that the data is correct by thoroughly analyzing and double-checking to make sure that the data is complete, error-free and high-quality.
# - It is an iterative process along with discovering, structuring, cleaning, joining and presenting
# - Questions to ask during vallidation:
#     - are all entries in same format
#     - are all entries in same range
#     - are all entries expressed in same data type
