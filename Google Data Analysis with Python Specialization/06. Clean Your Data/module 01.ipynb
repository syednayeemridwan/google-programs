# %% [markdown]
# # Handle missing value

# %% [markdown]
# - ask the owner to be sure first of all and request to fill in
# - Delete missing values
# - Create a NAN category
# - Filling in values with representative value
# - Investigate if data is randomly missing or there is a pattern in missing data
#
# ```python
# df = df.drop_duplicates(subset=['style', 'rating'])
# ```
