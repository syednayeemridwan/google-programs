# %% [markdown]
# # Organizing and Structuring

# %% [markdown]
# - Sorting = values from biggest to smallest
# - Grouping = bucketizing or affregating
# - Slicing = breaks data into smaller parts
# - Filtering = selecting smaller parts based on specific parameters
# - Extracting = process of retrieving new information from existing data
# - merge or join = combine dataset
