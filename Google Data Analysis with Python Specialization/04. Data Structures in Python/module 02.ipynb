# %% [markdown]
# # Dictionary

# %% [markdown]
# - dictionary keys are immutable
# - dictionary is ordered from python 3.7. but better to use ordered data structure if order is required

# %% [markdown]
# # Set

# %% [markdown]
# - Each set item is immutable. But set itself is mutable. so it cannot be used as keys in dictionary
# - set is a data structure that contains only unordered, non-interchangeable elements.
